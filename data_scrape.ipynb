# %%
from fastai.vision import *

# %%
folder = 'ring-necked'
file = 'urls_ring-necked'

# %%
path = Path('data/snakes')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [WindowsPath('data/snakes/.ipynb_checkpoints'),
#  WindowsPath('data/snakes/foxsnake'),
#  WindowsPath('data/snakes/Gray Ratsnake'),
#  WindowsPath('data/snakes/Ring-necked Snake'),
#  WindowsPath('data/snakes/Timber Rattlesnake'),
#  WindowsPath('data/snakes/urls_eastern_foxsnake')]

# %%
classes = ['foxsnake','ratsnake','ring-necked', 'rattlesnake']

# %%
download_images(path/file, dest, max_pics=200)

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# foxsnake
# ratsnake
# ring-necked
# rattlesnake

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['foxsnake', 'ratsnake', 'rattlesnake', 'ring-necked']

# %%
doc(data.show_batch)

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['foxsnake', 'ratsnake', 'rattlesnake', 'ring-necked'], 4, 484, 120)
